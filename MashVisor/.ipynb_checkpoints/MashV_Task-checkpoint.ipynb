# %% [markdown]
# <h1 style="text-align: center;">Property Analysis Task</h1>
# <br>
# By: Rami Tailakh
# <br>24 May 2017

# %%
# This section code to import all necessary packages required for this task
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get the Data

# %%
leads = pd.read_excel('Classification of Leads.xls')

# %%
leads.head()
# Out:
#    Mashvisor ID Lead Cities of Interest  \
# 0         20658                 Yonkers
# 1         20655             Springfield
# 2         20654                Coos Bay
# 3         20653                 Buffalo
# 4         20652                 Chicago
#
#   When did the lead start searching for a home?  \
# 0                           2017-07-12 07:27:00
# 1                           2017-07-12 06:49:00
# 2                           2017-07-12 05:59:00
# 3                           2017-07-12 05:38:00
# 4                           2017-07-12 01:05:00
#
#   When was the lead connected with an agent?  \
# 0                        2017-07-12 07:08:00
# 1                        2017-07-12 05:38:00
# 2                        2017-07-12 01:05:00
# 3                        2017-07-12 01:02:00
# 4                        2017-07-11 23:10:00
#
#   Financing Status at time connected with Agent:  \
# 0                        Applying for a mortgage
# 1                        Applying for a mortgage
# 2                        Applying for a mortgage
# 3                        Applying for a mortgage
# 4                        Applying for a mortgage
#
#   Financing Status at purchase:    Final status of lead:
# 0   Pre-Approved for a mortgage       Purchased Property
# 1   Pre-Approved for a mortgage          Submitted Offer
# 2                  Not sure yet          Submitted Offer
# 3       Applying for a mortgage          Submitted Offer
# 4                   Paying Cash  Searched for a Property

# %% [markdown]
# ## Data Preprocessing
# Here, we will basically look for any missings or defects in data. We will also

# %%
leads.describe()
# Out:
#        Mashvisor ID
# count   7188.000000
# mean   16913.425710
# std     2319.768839
# min      137.000000
# 25%    15103.750000
# 50%    16953.500000
# 75%    18798.250000
# max    20658.000000

# %% [markdown]
# In the next code, it can be seen that there are 92 null (or blank) values in the <b>Lead Cities of Interest</b> field. These observations, that have missing of the name of a city, will not be neglected, rather, it will be shown as <b>UNKOWN</b>.

# %%
leads.isnull().sum()
# Out:
# Mashvisor ID                                       0
# Lead Cities of Interest                           92
# When did the lead start searching for a home?      0
# When was the lead connected with an agent?         0
# Financing Status at time connected with Agent:     0
# Financing Status at purchase:                      0
# Final status of lead:                              0
# dtype: int64

# %%
leads['Lead Cities of Interest'] = leads['Lead Cities of Interest'].fillna('UNKNOWN')

# %% [markdown]
# The next code is to make sure that there are no extra spaces in city names, for instance, the computer machine will see that 'Chicago ' and 'Chicago' as two different cities.

# %%
leads['Lead Cities of Interest'] = leads['Lead Cities of Interest'].str.strip()

# %% [markdown]
# According to the next code, it can be seen that there are no missings.

# %%
leads.isnull().sum()
# Out:
# Mashvisor ID                                      0
# Lead Cities of Interest                           0
# When did the lead start searching for a home?     0
# When was the lead connected with an agent?        0
# Financing Status at time connected with Agent:    0
# Financing Status at purchase:                     0
# Final status of lead:                             0
# dtype: int64

# %% [markdown]
# In the follwoing code, we will add a new column to our dataset. This column will be used to represent the difference between <b>When did the lead start searching for a home</b> and <b>When was the lead connected with an agent</b>.

# %%
from datetime import datetime, timedelta
leads['days_diff'] = (leads['When was the lead connected with an agent?']-leads['When did the lead start searching for a home?']).astype('timedelta64[D]')

# %%
import pandas as pd
import datetime

def days_parse(s,e):
    td = pd.Timedelta(s - e) # -datetime.datetime.strptime(e,'%Y-%m-%d')
    return td/ np.timedelta64(1, 'D')

leads['days_diff'] = leads.apply(lambda x: days_parse(x['When was the lead connected with an agent?'], x['When did the lead start searching for a home?']), axis=1)

#leads['When was the lead connected with an agent?','When did the lead start searching for a home?'].apply(parse_date)
#,'When did the lead start searching for a home?'

# %%
leads
# Out:
#       Mashvisor ID       Lead Cities of Interest  \
# 0            20658                       Yonkers
# 1            20655                   Springfield
# 2            20654                      Coos Bay
# 3            20653                       Buffalo
# 4            20652                       Chicago
# 5            20631                          Waco
# 6            20630                      San Jose
# 7            20629                     San Mateo
# 8            20628                         Arden
# 9            20626                       Phoenix
# 10           20625                        Dallas
# 11           20624                      Portland
# 12           20623                        Destin
# 13           20622                       Houston
# 14           20621                        Edison
# 15           20620                       Montauk
# 16           20619                       Liberty
# 17           20617                       Houston
# 18           20616                   Panama City
# 19           20615                       UNKNOWN
# 20           20614              Huntington Beach
# 21           20613                     Arlington
# 22           20612                    Wilmington
# 23           20611                   Palm Harbor
# 24           20610                       Chicago
# 25           20608                   Jersey City
# 26           20591                     Rosendale
# 27           20587                        Boston
# 28           20582                      New York
# 29           20581                  Santa Monica
# ...            ...                           ...
# 7158         13402                       Leander
# 7159         13401              Western Virginia
# 7160         13398                         Miami
# 7161         13393                       Buffalo
# 7162         13382                         Miami
# 7163         13377                       Phoenix
# 7164         13372                    Washington
# 7165         13366                 San Francisco
# 7166         13360                   Los Angeles
# 7167         13359               Pensacola Beach
# 7168         13352                      New York
# 7169         13351                        Kailua
# 7170         13347                        Tacoma
# 7171         13343                    Pleasanton
# 7172         13342                  Lake Charles
# 7173         13341                Salt Lake City
# 7174         13339  Bronx, Brooklyn, Jersey City
# 7175         13334                         Miami
# 7176         13333             Panama City Beach
# 7177         13331                    Charleston
# 7178         13329            Jacksonville Beach
# 7179         13328                 Oklahoma City
# 7180         13322                       Chicago
# 7181         13320                 San Francisco
# 7182         13308                        Austin
# 7183         13305                     Las Vegas
# 7184         13303                  Palm Springs
# 7185         13302                    Somerville
# 7186         13300                       Chicago
# 7187         13299                      Munising
#
#      When did the lead start searching for a home?  \
# 0                              2017-07-12 07:27:00
# 1                              2017-07-12 06:49:00
# 2                              2017-07-12 05:59:00
# 3                              2017-07-12 05:38:00
# 4                              2017-07-12 01:05:00
# 5                              2017-07-11 15:27:00
# 6                              2017-07-11 10:53:00
# 7                              2017-07-11 14:32:00
# 8                              2017-07-11 13:55:00
# 9                              2017-07-11 13:41:00
# 10                             2017-07-11 13:38:00
# 11                             2017-07-11 13:36:00
# 12                             2017-07-11 13:35:00
# 13                             2017-07-11 13:21:00
# 14                             2017-07-11 12:49:00
# 15                             2017-07-11 12:48:00
# 16                             2017-07-11 12:47:00
# 17                             2017-07-11 11:39:00
# 18                             2017-07-11 11:32:00
# 19                             2017-07-11 11:32:00
# 20                             2017-07-11 11:27:00
# 21                             2017-07-11 11:06:00
# 22                             2017-07-11 11:06:00
# 23                             2017-07-11 10:56:00
# 24                             2017-07-11 10:44:00
# 7175                        2017-03-19 21:51:00
# 7176                        2017-03-19 21:08:00
# 7177                        2017-03-19 20:40:00
# 7178                        2017-03-19 17:45:00
# 7179                        2017-03-19 16:41:00
# 7180                        2017-03-19 10:26:00
# 7181                        2017-03-19 09:59:00
# 7182                        2017-03-18 19:58:00
# 7183                        2017-03-18 19:21:00
# 7184                        2017-03-18 15:20:00
# 7185                        2017-03-18 14:38:00
# 7186                        2017-03-18 12:41:00
# 7187                        2017-03-18 11:52:00
#
#      Financing Status at time connected with Agent:  \
# 0                           Applying for a mortgage
# 1                           Applying for a mortgage
# 2                           Applying for a mortgage
# 3                           Applying for a mortgage
# 4                           Applying for a mortgage
# 5                           Applying for a mortgage
# 6                           Applying for a mortgage
# 7                           Applying for a mortgage
# 8                           Applying for a mortgage
# 9                           Applying for a mortgage
# 10                          Applying for a mortgage
# 11                          Applying for a mortgage
# 12                          Applying for a mortgage
# 13                          Applying for a mortgage
# 14                          Applying for a mortgage
# 15                          Applying for a mortgage
# 16                          Applying for a mortgage
# 17                          Applying for a mortgage
# 18                          Applying for a mortgage
# 19                          Applying for a mortgage
# 20                          Applying for a mortgage
# 21                          Applying for a mortgage
# 22                          Applying for a mortgage
# 23                          Applying for a mortgage
# 24                          Applying for a mortgage
# 25                          Applying for a mortgage
# 26                          Applying for a mortgage
# 27                          Applying for a mortgage
# 28                          Applying for a mortgage
# 29                          Applying for a mortgage
# ...                                             ...
# 7158                    Pre-Approved for a mortgage
# 7159                    Pre-Approved for a mortgage
# 7160                    Pre-Approved for a mortgage
# 7161                    Pre-Approved for a mortgage
# 7162                    Pre-Approved for a mortgage
# 7163                    Pre-Approved for a mortgage
# 7164                    Pre-Approved for a mortgage
# 7165                    Pre-Approved for a mortgage
# 7166                    Pre-Approved for a mortgage
# 7167                    Pre-Approved for a mortgage
# 7168                    Pre-Approved for a mortgage
# 7169                    Pre-Approved for a mortgage
# 7170                    Pre-Approved for a mortgage
# 7171                    Pre-Approved for a mortgage
# 7172                    Pre-Approved for a mortgage
# 7173                    Pre-Approved for a mortgage
# 7174                    Pre-Approved for a mortgage
# 7175                    Pre-Approved for a mortgage
# 7176                    Pre-Approved for a mortgage
# 7177                    Pre-Approved for a mortgage
# 7178                    Pre-Approved for a mortgage
# 7179                    Pre-Approved for a mortgage
# 7180                    Pre-Approved for a mortgage
# 7181                    Pre-Approved for a mortgage
# 7182                    Pre-Approved for a mortgage
# 7183                    Pre-Approved for a mortgage
# 7184                    Pre-Approved for a mortgage
# 7185                    Pre-Approved for a mortgage
# 7186                    Pre-Approved for a mortgage
# 7187                    Pre-Approved for a mortgage
#
#      Financing Status at purchase:     Final status of lead:  days_diff
# 0      Pre-Approved for a mortgage        Purchased Property  -0.013194
# 1      Pre-Approved for a mortgage           Submitted Offer  -0.049306
# 2                     Not sure yet           Submitted Offer  -0.204167
# 3          Applying for a mortgage           Submitted Offer  -0.191667
# 4                      Paying Cash   Searched for a Property  -0.079861
# 5                     Not sure yet    Lead is Not Responsive   0.399306
# 6                      Paying Cash           Submitted Offer   0.222917
# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Please note that the proposed solutin was dealing each part of each question independently.
# #### 1. What’s the likelihood that the ‘Final status of lead’ is ‘Purchased Property’ if:

# %% [markdown]
# Financing status at time connected with Agent is ‘Applying for a mortgage’

# %%
leads_1_a = leads[(leads['Final status of lead:'] == 'Purchased Property') & (leads['Financing Status at time connected with Agent:'] == 'Applying for a mortgage')]
((leads_1_a.size/leads.size).round(2) * 100).astype('int').astype('str')+'%'
# Out:
# '11%'

# %% [markdown]
# Financing status at purchase is ‘Paying Cash’

# %%
leads_1_b = leads[(leads['Final status of lead:'] == 'Purchased Property') & (leads['Financing Status at purchase:'] == 'Paying Cash')]
((leads_1_b.size/leads.size).round(2) * 100).astype('int').astype('str')+'%'
# Out:
# '6%'

# %% [markdown]
# #### 2. What’s the likelihood that the ‘Final status of lead’ is ‘Purchased Property’ if the difference between ‘When did the lead start searching for a home’ and ‘When was the lead connected with an agent is:
# <ul>
# <li>2 Days</li>
# <li>3 Day</li>
# <li>4 Day</li>
# <li>5 & more Days</li>
# </ul>

# %%
leads_2_2d = leads[((leads['days_diff'] >= 2.0) &(leads['days_diff'] < 3.0)) & (leads['Final status of lead:'] == 'Purchased Property')]
print('2 Days: ', ((leads_2_2d.size/leads.size).round(2) * 100).astype('int').astype('str'),'%')
leads_2_3d = leads[((leads['days_diff'] >= 3.0) &(leads['days_diff'] < 4.0)) & (leads['Final status of lead:'] == 'Purchased Property')]
print('3 Days: ', ((leads_2_3d.size/leads.size).round(2) * 100).astype('int').astype('str'),'%')
leads_2_4d = leads[((leads['days_diff'] >= 4.0) &(leads['days_diff'] < 5.0)) & (leads['Final status of lead:'] == 'Purchased Property')]
print('4 Days: ', ((leads_2_4d.size/leads.size).round(2) * 100).astype('int').astype('str'),'%')
leads_2_5d = leads[(leads['days_diff'] >= 5.0) & (leads['Final status of lead:'] == 'Purchased Property')]
print('5 Days & more: ', ((leads_2_5d.size/leads.size).round(2) * 100).astype('int').astype('str'),'%')
# Out:
# 2 Days:  1 %
# 3 Days:  0 %
# 4 Days:  0 %
# 5 Days & more:  26 %

# %% [markdown]
# #### 3. What ‘Lead Cities’ have the highest probability to be ‘Purchased Property’ as Final status of lead?

# %%
leads_3 = leads[leads['Final status of lead:'] == 'Purchased Property']
leads_3_count = leads_3.groupby(['Lead Cities of Interest']).agg(['count'])
leads_3_count.idxmax()[1]
# Out:
# 'Chicago'

# %%
# number of observations
len(leads[(leads['Final status of lead:'] == 'Purchased Property') & (leads['Lead Cities of Interest'] == 'Chicago')])
# Out:
# 302

# %%
leads['When did the lead start searching for a home?'].map(lambda x: x.strftime('%Y-%m')).unique()
# Out:
# array(['2017-07', '2017-06', '2017-05', '2017-04', '2017-03'], dtype=object)

# %% [markdown]
# The above results give the likelihood according to the given criteria in this task, however, the given results could only be valid for the months: March, April, May, June and July for the given cities. In other words, these results may not be generalized for new data, and specifically, new cities or months of a year. Nonetheless, we can restructure our dataset where we can add a new column categorizing time difference between: start searching for a home and connecting with agent, in categories such as: less than 2 days, 2 days, 3 days, 4 days, and 5 & more. Then, machine learning models can be employed to help have better prediction results of the final status of lead. However, "the more data the better", that is, it would be more useful, if data, reprents a whole year, was utilized in this task.
