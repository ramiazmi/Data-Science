# %%
# conda search seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
#%matplotlib inline

# %%
df_swing = pd.read_csv('2008_swing_states.csv')
df_swing
# Out:
#       ﻿year state                                       county   fips  \
# 0      2008    AL                               Autauga County   1001
# 1      2008    AL                               Baldwin County   1003
# 2      2008    AL                               Barbour County   1005
# 3      2008    AL                                  Bibb County   1007
# 4      2008    AL                                Blount County   1009
# 5      2008    AL                               Bullock County   1011
# 6      2008    AL                                Butler County   1013
# 7      2008    AL                               Calhoun County   1015
# 8      2008    AL                              Chambers County   1017
# 9      2008    AL                              Cherokee County   1019
# 10     2008    AL                               Chilton County   1021
# 11     2008    AL                               Choctaw County   1023
# ...

# %%
df_swing[['state','county','pct_dem']]
# Out:
#      state                                       county  pct_dem
# 0       AL                               Autauga County    25.80
# 1       AL                               Baldwin County    23.80
# 2       AL                               Barbour County    49.00
# 3       AL                                  Bibb County    26.60
# 4       AL                                Blount County    14.50
# 5       AL                               Bullock County    74.10
# 6       AL                                Butler County    43.10
# 7       AL                               Calhoun County    33.20
# 8       AL                              Chambers County    45.50
# 9       AL                              Cherokee County    23.70
# 10      AL                               Chilton County    20.70
# 11      AL                               Choctaw County    46.10
# 12      AL                                Clarke County    44.00
# ...

# %%
df_swing.head()
# Out:
#    ﻿year state          county  fips  vote_rep  vote_dem  vote_oth  \
# 0   2008    AL  Autauga County  1001     17403      6093       145
# 1   2008    AL  Baldwin County  1003     61271     19386       756
# 2   2008    AL  Barbour County  1005      5866      5697        67
# 3   2008    AL     Bibb County  1007      6262      2299        83
# 4   2008    AL   Blount County  1009     20389      3522       356
#
#    vote_total  pct_rep  pct_dem  pct_oth winner runnerup  pct_winner  \
# 0       23641     73.6     25.8      0.6    rep      dem        73.6
# 1       81413     75.3     23.8      0.9    rep      dem        75.3
# 2       11630     50.4     49.0      0.6    rep      dem        50.4
# 3        8644     72.4     26.6      1.0    rep      dem        72.4
# 4       24267     84.0     14.5      1.5    rep      dem        84.0
#
#    margin_winner_over_runnerup
# 0                         47.8
# 1                         51.5
# 2                          1.4
# ...

# %%
df_states = df_swing[df_swing.state == 'OH']
df_states.append(df_swing[df_swing.state == 'PA'])
df_states.append(df_swing[df_swing.state == 'FL'])
# Out:
#       ﻿year state              county   fips  vote_rep  vote_dem  vote_oth  \
# 2014   2008    OH        Adams County  39001      6914      4170       304
# 2015   2008    OH        Allen County  39003     29940     19522       801
# 2016   2008    OH      Ashland County  39005     15158      9300       710
# 2017   2008    OH    Ashtabula County  39007     18949     25027       898
# 2018   2008    OH       Athens County  39009      9742     20722       634
# 2019   2008    OH     Auglaize County  39011     16395      6727       364
# 2020   2008    OH      Belmont County  39013     15422     16302       687
# 2021   2008    OH        Brown County  39015     12192      7503       418
# 2022   2008    OH       Butler County  39017    105341     66030      2406
# 2023   2008    OH      Carroll County  39019      7097      6423       433
# 2024   2008    OH    Champaign County  39021     11141      7385       361
# ...

# %%
bin_edges = [0, 20,30, 40, 50, 60, 70, 80, 90, 100]
_= plt.hist(df_swing['pct_dem'], bins = bin_edges)
_= plt.xlabel('Votes for Obama')
_= plt.ylabel('Number of Counties')
plt.show()

# %%
df_states_oh = df_swing[df_swing.state == 'OH']
df_states_pa = df_states_oh.append(df_swing[df_swing.state == 'PA'])
df_states_fl = df_states_pa.append(df_swing[df_swing.state == 'FL'])
_= sns.swarmplot(x='state',y='pct_dem', data=df_states_fl)
_= plt.xlabel('states')
_= plt.ylabel('percentage of vote for obama')
plt.show()

# %%
x = np.sort(df_swing['pct_dem'])
y = np.arange(1,len(x)+1)/len(x)
_= plt.plot(x,y,marker='.', linestyle='none')
_= plt.xlabel('percentage of vote for obama')
_= plt.ylabel('ECDF')
plt.margins(0.02)
plt.axis([0,100,0,1])
plt.show()

# %%
def ecdf(ds):
    x = np.sort(ds)
    n = len(x)
    y = np.arange(1, n+1) / n
    return x, y

# %%
df_OH = df_swing[df_swing.state == 'OH']
df_FL = df_swing[df_swing.state == 'FL']
df_PA = df_swing[df_swing.state == 'PA']

x_OH, y_OH = ecdf(df_OH['pct_dem'])
x_PA, y_PA = ecdf(df_PA['pct_dem'])
x_FL, y_FL = ecdf(df_FL['pct_dem'])

_= plt.plot(x_OH, y_OH, marker='.', linestyle='none')
_= plt.plot(x_PA, y_PA, marker='.', linestyle='none')
_= plt.plot(x_FL, y_FL, marker='.', linestyle='none')

plt.margins(0.02)

_= plt.xlabel('percentage')
_= plt.ylabel('ECDF')
_= plt.legend(('OH','FL','PA'))
plt.show()

# %%
# df_states_oh = df_swing[df_swing.state == 'OH']
# df_states_pa = df_states_oh.append(df_swing[df_swing.state == 'PA'])
# df_states_fl = df_states_pa.append(df_swing[df_swing.state == 'FL'])
# _= sns.swarmplot(x='winner',y='pct_dem', data=df_swing)
# _= plt.xlabel('Winner')
# _= plt.ylabel('percentage of vote for obama')
# plt.show()

# %%
np.median(df)
# Out:
# 42.600000000000001

# %%
np.std(df)
# Out:
# 9.676363390146173

# %%
np.std(df_OH['pct_dem'])
# Out:
# 9.676363390146173

# %%
np.std(df_PA['pct_dem'])
# Out:
# 9.67478041251047

# %%
np.std(df_FL['pct_dem'])
# Out:
# 12.093094373298216

# %%
_= sns.boxplot(x='winner', y='pct_dem', data = df_swing)
_= plt.xlabel('Winner')
_= plt.ylabel('percentage of vote for obama')
axis = plt.gca()
axis.set_ylim([0,100])
plt.show()

# %%
_= sns.boxplot(x='winner', y='pct_rep', data = df_swing)
_= plt.xlabel('Winner')
_= plt.ylabel('percentage of vote for obama')
axis = plt.gca('')
axis.set_ylim([0,100])
plt.show()

# %%
df_OH = df_swing[df_swing.state == 'OH']
mean_OH = np.mean(df_OH['pct_dem'])
median_OH = np.median(df_OH['pct_dem'])
std_OH = np.std(df_OH['pct_dem'])
variance_OH = np.var(df_OH['pct_dem'])
_= sns.swarmplot(x='state',y='pct_dem', data=df_OH)
_= plt.xlabel('states')
_= plt.ylabel('percentage of vote for obama')
# plt.axhline(y=mean_OH, label='Mean')
# plt.axhline(y=median_OH, label='Median')
# _=plt.axhline(y=std_OH, color='red', zorder=2)
_=plt.axhline(y=variance_OH, color='green', zorder=2)
plt.legend()
plt.show()
# Out:
# /Users/Rami/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
_=plt.plot(df_swing['vote_total']/1000,df_swing['pct_dem'],marker='.',linestyle='none')
_= plt.xlabel('Total votes')
_= plt.ylabel('percentage of vote for obama')
axis = plt.gca()
axis.set_xlim([0,1000])#max(df_swing['vote_total'])/10000
axis.set_ylim([0,100])
mean = np.mean(df_swing['pct_dem'])
_=plt.axvline(x=mean, color='green', zorder=2)
mean_2 = np.mean(df_swing['vote_total']/1000)
_=plt.axhline(y=mean_2, color='red', zorder=2)
plt.legend()
plt.show()

# %%
std_y = np.std(df_swing['pct_dem'])
_=plt.axvline(x=mean, color='green', zorder=2)
std_x = np.std(df_swing['vote_total']/1000)
covariance = np.cov(df_swing['vote_total']/1000, df_swing['pct_dem'], bias=True)[0][1]

# %%
covariance
# Out:
# 641.57704848066021

# %%
corr = covariance/(std_y*std_x)

# %% [raw]
# corr

# %%
np.corrcoef(x, y)
